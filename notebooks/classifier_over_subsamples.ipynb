# %%
import pandas as pd
import numpy as np
import os
import torch
import matplotlib.pyplot as plt

import torch
from torch import nn
from torch.utils.data import TensorDataset, DataLoader


from sklearn import linear_model
from sklearn.neural_network import MLPClassifier
from sklearn.linear_model import LinearRegression
from sklearn.metrics import roc_auc_score, confusion_matrix

import matplotlib.pyplot as plt
import subprocess
plt.rcParams['svg.fonttype'] = 'none'

# %%
def run_python_script(args, cwd=None):
    """
    Executes a Python script with the given arguments list in the specified directory.
    Prints STDOUT in real time.
    The first element should be the script path, followed by its arguments.
    Example: ["other_script.py", "--foo", "bar"]
    """
    cmd = ["python"] + args
    print("Running command:", " ".join(cmd))
    process = subprocess.Popen(
        cmd,
        stdout=subprocess.PIPE,
        stderr=subprocess.PIPE,
        text=True,
        cwd=cwd
    )

    while True:
        stdout_line = process.stdout.readline()
        if stdout_line:
            print(stdout_line, end="", flush=True)
        elif process.poll() is not None:
            break

    for line in process.stdout:
        print(line, end="", flush=True)

    stderr = process.stderr.read()
    if stderr:
        print("\n--- STDERR ---\n", stderr)

    process.stdout.close()
    process.stderr.close()
    return process

# %%
args = ["./train_classifiers_over_subsamples.py"]
run_python_script(args, cwd=os.path.abspath("./"))
# Out:
# Running command: python ./train_classifiers_over_subsamples.py
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 args = ["./train_classifiers_over_subsamples.py"]
# ----> 2 run_python_script(args, cwd=os.path.abspath("./"))
#
# Cell In[4], line 19, in run_python_script(args, cwd)
#      10 process = subprocess.Popen(
#      11     cmd,
#      12     stdout=subprocess.PIPE,
#    (...)
#      15     cwd=cwd
#      16 )
#      18 while True:
# ---> 19     stdout_line = process.stdout.readline()
#      20     if stdout_line:
#      21         print(stdout_line, end="", flush=True)
#
# KeyboardInterrupt:

# %%
subsamples_dir = "data/gfp/subsamples/new/"
files = os.listdir(subsamples_dir)

files = [f for f in files if f.startswith("s_") and f.endswith(".csv")]

import pandas as pd


df_list = []
for file in files:
    file_path = os.path.join(subsamples_dir, file)
    df = pd.read_csv(file_path)
    df["source_file"] = file  
    if "ohe" in file:
        df["model"] = "ohe"
    elif "llm" in file:
        df["model"] = "esm"

    df_list.append(df)

all_data = pd.concat(df_list, ignore_index=True)
all_data
# Out:
#         tp      tn      fp     fn  precision    recall        f1  accuracy  \
# 0    18624  372580    6615  14701   0.737906  0.558860  0.636022  0.948327
# 1    18790  330800   56326  15507   0.250146  0.547861  0.343469  0.829547
# 2    25626  169016  218112   8669   0.105137  0.747223  0.184338  0.461868
# 3    24547  271504  115624   9748   0.175122  0.715760  0.281396  0.702503
# 4     8739  368576   18550  25558   0.320239  0.254804  0.283798  0.895336
# ..     ...     ...     ...    ...        ...       ...       ...       ...
# 135   7301  329864   57262  26996   0.113083  0.212876  0.147704  0.800063
# 136   8214  304963   82163  26083   0.090886  0.239496  0.131768  0.743142
# 137  13792  245173  141954  20504   0.088554  0.402146  0.145147  0.614501
# 138  32079   51493  335636   2215   0.087239  0.935411  0.159593  0.198309
# 139  10305  268210  118917  23991   0.079746  0.300472  0.126041  0.660892
#
#           roc  top_100_pct  fraction  iter  \
# 0    0.930926         1.00      0.03     0
# 1    0.796907         0.45      0.03     1
# 2    0.643532         0.14      0.03     2
# 3    0.766338         0.75      0.03     3
# 4    0.687911         0.45      0.03     4
# ..        ...          ...       ...   ...
# 135  0.521788         0.27      0.10     5
# 136  0.510952         0.04      0.10     6
# 137  0.508983         0.04      0.10     7
# 138  0.608081         0.07      0.10     8
# 139  0.480533         0.01      0.10     9
#
#                                           source_file model
# 0    s_across_iterations_ohe_fraction_new_0.03000.csv   ohe
# 1    s_across_iterations_ohe_fraction_new_0.03000.csv   ohe
# 2    s_across_iterations_ohe_fraction_new_0.03000.csv   ohe
# 3    s_across_iterations_ohe_fraction_new_0.03000.csv   ohe
# 4    s_across_iterations_ohe_fraction_new_0.03000.csv   ohe
# ..                                                ...   ...
# 135  s_across_iterations_llm_fraction_new_0.10000.csv   esm
# 136  s_across_iterations_llm_fraction_new_0.10000.csv   esm
# 137  s_across_iterations_llm_fraction_new_0.10000.csv   esm
# 138  s_across_iterations_llm_fraction_new_0.10000.csv   esm
# 139  s_across_iterations_llm_fraction_new_0.10000.csv   esm
#
# [140 rows x 14 columns]

# %%
files
# Out:
# []

# %%
plt.figure(figsize=(2, 2))
colors = {"ohe": "#5d0187", "esm": "#f0b800"}

grouped = (
    all_data.groupby(["fraction", "model"])["roc"]
    .agg(["median", "std"])
    .reset_index()
)

for model in grouped["model"].unique():
    data = grouped[grouped["model"] == model]
    plt.plot(
        data["fraction"], data["median"], label=f"ROC (mean) ({model})", color=colors.get(model, None)
    )
    # plt.fill_between(
    #     data["fraction"],
    #     data["mean"] - data["std"],
    #     data["mean"] + data["std"],
    #     color=colors.get(model, None), alpha=0.3, label=f"ROC (mean ± SD) ({model})"
    # )
    plt.errorbar(
        data["fraction"], data["median"], yerr=data["std"], color=colors.get(model, None), capsize=4
    )

plt.xlabel("Fraction of sequences")
plt.ylabel("ROC (AUC)")
#plt.legend()
plt.tight_layout()
plt.show()

output_dir = "./figures/figure_3"
#plt.savefig(os.path.join(output_dir, "roc_auc_gfp_as_func_of_sequences.svg"), bbox_inches='tight')
plt.close()

# %%
all_data
# Out:
#         tp      tn     fp     fn  precision    recall        f1  accuracy  \
# 0     9338  429270  10152  22275   0.479117  0.295385  0.365458  0.931158
# 1     9671  427343  12133  21888   0.443542  0.306442  0.362461  0.927774
# 2     9127  428201  11269  22438   0.447490  0.289149  0.351302  0.928441
# 3     9534  430792   8627  22082   0.524971  0.301556  0.383068  0.934805
# 4     8695  428938  10426  22976   0.454736  0.274541  0.342377  0.929088
# ..     ...     ...    ...    ...        ...       ...       ...       ...
# 155  17877  433728   5679  13751   0.758915  0.565227  0.647905  0.958750
# 156  18048  433631   5841  13515   0.755494  0.571809  0.650941  0.958908
# 157  18062  433521   5898  13554   0.753840  0.571293  0.649993  0.958704
# 158  17854  433815   5613  13753   0.760813  0.564875  0.648364  0.958886
# 159  18152  433721   5748  13414   0.759498  0.575049  0.654527  0.959319
#
#           roc  top_100_pct  fraction  iter  \
# 0    0.787164         1.00       0.1     0
# 1    0.766998         0.96       0.1     1
# 2    0.772095         0.98       0.1     2
# 3    0.787387         0.99       0.1     3
# 4    0.757846         0.93       0.1     4
# ..        ...          ...       ...   ...
# 155  0.930950         1.00       0.1     5
# 156  0.933008         1.00       0.1     6
# 157  0.930669         1.00       0.1     7
# 158  0.932429         1.00       0.1     8
# 159  0.932611         1.00       0.1     9
#
#                                      source_file model
# 0    n_across_iterations_llm_fraction_0.1000.csv   esm
# 1    n_across_iterations_llm_fraction_0.1000.csv   esm
# 2    n_across_iterations_llm_fraction_0.1000.csv   esm
# 3    n_across_iterations_llm_fraction_0.1000.csv   esm
# 4    n_across_iterations_llm_fraction_0.1000.csv   esm
# ..                                           ...   ...
# 155  n_across_iterations_ohe_fraction_0.1000.csv   ohe
# 156  n_across_iterations_ohe_fraction_0.1000.csv   ohe
# 157  n_across_iterations_ohe_fraction_0.1000.csv   ohe
# 158  n_across_iterations_ohe_fraction_0.1000.csv   ohe
# 159  n_across_iterations_ohe_fraction_0.1000.csv   ohe
#
# [160 rows x 14 columns]
